# %% [markdown]
# <a href="https://colab.research.google.com/github/SaulMendozaB/Algoritmos-y-Estructuras-de-Datos/blob/main/Ejercicio2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile Biblioteca.hpp
# //Definicion de bibliotecas, clases y funciones
# #include <iostream>
# #include <cstdlib>// srand, rand
# #include <ctime>//time
#
# using std::cout;
# using std::cin;
# template <typename Generico>
#
# class MyVector{
#     Generico* a;
#
#     size_t n;
#
#     public:
#
#     MyVector(){a=new Generico[100]; n=0;}
#
#     void generar(short* a, size_t n){
#   for(size_t i=0;i<n;++i){
#       a[i]=rand()%101+100;//rango de 100 a 200
#    }
#   }
#   void listar(short* a, size_t n){
# for(size_t i=0;i<n;++i){
#       cout<<i<<"-> "<<a[i]<<"\n";
#   }
# }
#
# void mayor(short* a, size_t n){
#   short _mayor=a[0], _pos=-1;
#
# for(size_t i=1;i<n;++i){
#   if(a[i]>_mayor){
#       _mayor=a[i];//actualizo el mayor
#       _pos=i;
#     }
#   }
#   cout<<"El mayor valor es"<<_mayor<<" y se encuentra en la posicion"<<_pos<<"\n";
# }
# void ordenar(short* a, size_t n){
#   for(int i=0;i<n-1;++i){
#   for(int j=i+1;j<n;++j){
#    if(a[i]>a[j]){
#     short aux=a[i];
#     a[i]=a[j];
#     a[j]=aux;
#   }
# }
#     }
# }
# void mayorPromedio(short* a, size_t n){
#   float prom=0.0f;
#   //obteniendo el promedio
#   for(int i=0;i<n-1;++i)
#         prom+=a[i];
#   prom/=n;//prom=prom/n
#   //listar mayor al promedio
#   for(int i=0;i<n-1;++i)
#         if(a[i]>prom)cout<<i<<"->"<<a[i]<<"\n";
#   }
# };
# Out:
# Overwriting Biblioteca.hpp

# %%
# %%writefile ejemplo2.cpp
# #include<iostream>
# #include "Biblioteca.hpp"
#
# using namespace std;
#
# int main(){
#     short* arreglo=new short[100];
# srand(time(NULL));//inicializacion de la semilla
#
#     MyVector<int>*arr1 =new  MyVector<int>;
#
#
#
#     for(size_t i=0;  i<100; i++){
#         arr1->generar(arreglo,100);
#
#     }
#
#        arr1->listar(arreglo, 100);
#         //mayor(arreglo, 100);
#         arr1->ordenar(arreglo, 100);
#         cout<<"-------------\n";
#         //listar(arreglo, 100);
#         arr1->mayorPromedio(arreglo, 100);
#
# }
# Out:
# Overwriting ejemplo2.cpp

# %%
# !g++ -std=c++1z Biblioteca.hpp ejemplo2.cpp && ./a.out
# Out:
# 0-> 191
# 1-> 152
# 2-> 142
# 3-> 179
# 4-> 177
# 5-> 181
# 6-> 192
# 7-> 154
# 8-> 152
# 9-> 199
# 10-> 147
# 11-> 188
# 12-> 150
# 13-> 131
# 14-> 197
# 15-> 174
# 16-> 192
# 17-> 114
# 18-> 114
# 19-> 169
# 20-> 153
# 21-> 130
# 22-> 160
# 23-> 191
# 24-> 135
# 25-> 154
# 26-> 179
# 27-> 153
# 28-> 105
# 29-> 110
# 30-> 185
# 31-> 162
# 32-> 163
# 33-> 193
# 34-> 140
# 35-> 105
# 36-> 139
# 37-> 131
# 38-> 125
# 39-> 157
# 40-> 196
# 41-> 172
# 42-> 110
# 43-> 146
# 44-> 169
# 45-> 107
# 46-> 186
# 47-> 127
# 48-> 188
# 49-> 200
# 50-> 162
# 51-> 141
# 52-> 129
# 53-> 188
# 54-> 198
# 55-> 164
# 56-> 107
# 57-> 176
# 58-> 184
# 59-> 180
# 60-> 153
# 61-> 134
# 62-> 141
# 63-> 115
# 64-> 126
# 65-> 148
# 66-> 187
# 67-> 165
# 68-> 145
# 69-> 178
# 70-> 121
# 71-> 141
# 72-> 149
# 73-> 132
# 74-> 187
# 75-> 185
# 76-> 105
# 77-> 172
# 78-> 178
# 79-> 193
# 80-> 138
# 81-> 139
# 82-> 200
# 83-> 167
# 84-> 194
# 85-> 198
# 86-> 198
# 87-> 100
# 88-> 139
# 89-> 147
# 90-> 180
# 91-> 192
# 92-> 181
# 93-> 121
# 94-> 173
# 95-> 106
# 96-> 135
# 97-> 125
# 98-> 137
# 99-> 180
# -------------
# 50->157
# 51->160
# 52->162
# 53->162
# 54->163
# 55->164
# 56->165
# 57->167
# 58->169
# 59->169
# 60->172
# 61->172
# 62->173
# 63->174
# 64->176
# 65->177
# 66->178
# 67->178
# 68->179
# 69->179
# 70->180
# 71->180
# 72->180
# 73->181
# 74->181
# 75->184
# 76->185
# 77->185
# 78->186
# 79->187
# 80->187
# 81->188
# 82->188
# 83->188
# 84->191
# 85->191
# 86->192
# 87->192
# 88->192
# 89->193
# 90->193
# 91->194
# 92->196
# 93->197
# 94->198
# 95->198
# 96->198
# 97->199
# 98->200
